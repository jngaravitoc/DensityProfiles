# %%
# %pylab inline
from profiles import *
from galpy.potential import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
r = linspace(0, 12)
plot(r/8.0, dens_hernquist(10, r, 1E12))

# %%
HP = HernquistPotential(1, a = 10)

# %%
HP.plot()

# %%
evaluatePotentials?

# %%
evaluatePotentials(1., 1.,HernquistPotential)
# Out:
# ---------------------------------------------------------------------------
# PotentialError                            Traceback (most recent call last)
# <ipython-input-22-9cb985974794> in <module>()
# ----> 1 evaluatePotentials(1., 1.,HernquistPotential)
#
# /usr/local/lib/python2.7/dist-packages/galpy/potential_src/Potential.pyc in evaluatePotentials(R, z, Pot, phi, t, dR, dphi)
#    1219         return Pot(R,z,phi=phi,t=t,dR=dR,dphi=dphi)
#    1220     else: #pragma: no cover
# -> 1221         raise PotentialError("Input to 'evaluatePotentials' is neither a Potential-instance or a list of such instances")
#    1222
#    1223 def evaluateDensities(R,z,Pot,phi=0.,t=0.,forcepoisson=False):
#
# PotentialError: "Input to 'evaluatePotentials' is neither a Potential-instance or a list of such instances"

# %%
evaluatePotentials(1.,0.,MWPotential2014)
# Out:
# -1.3733506513947895
